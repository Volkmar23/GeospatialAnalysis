# %% [markdown]
# ## Descarga de modelos climaticos
#
#
#
# Link : https://www.nccs.nasa.gov/services/data-collections/land-based-products/nex-gddp-cmip6

# %%
from GPDX_pr import verify_completeness,main_download

# %%
path_folder = r"D:\OneDrive\OneDrive - INTERCONEXION ELECTRICA S.A. E.S.P\01_CC_DOC\1_Raw_Data\4_Rain\02_NasaGPDX_SouthAmericaV3"

# %% [markdown]
# ### 1. Verificar que los archivos esten.
#
#
# `Completo`

# %%
verify_completeness(path_folder)
# Out:
# Starting download at :2025-03-19 13:07:53
#
# Modelo = GFDL-ESM4
#
# Ventana futura : (2015, 2100)
# Ventana Pasado : (1985, 2015)
# Escenario	:historical
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp245
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp370
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp585
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
#
#
# Modelo = MIROC6
#
# Ventana futura : (2015, 2100)
# Ventana Pasado : (1985, 2015)
# Escenario	:historical
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp245
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp370
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# Escenario	:ssp585
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
#
#
# Modelo = MPI-ESM1-2-HR
#
# Ventana futura : (2015, 2100)
# Ventana Pasado : (1985, 2015)
# Escenario	:historical
# lon :	(0.125,359.875)
# lat :	(-59.875,89.875)
#
#
# ...

# %% [markdown]
# ### 2. Descarga de archivos

# %%
main_download(path_folder)
# Out:
# Starting download at :2025-03-19 13:37:13
#
# ...
# Latitud boundaries : (-53.43306775676489, 13.592638486971083)
# Longitude boundaries : (-84.0833129206595, -34.73304413246237)
#
#
# Folder emppy , all good to proccede
# Current amount of files in folder 0
#
# Files are going into
#  D:\OneDrive\OneDrive - INTERCONEXION ELECTRICA S.A. E.S.P\01_CC_DOC\1_Raw_Data\4_Rain\02_NasaGPDX_SouthAmericaV3
#
# After 0-360 transformation (275.9166870793405, 325.2669558675376)
# Downloding files from GPDX Files.
#
# Modelo = GFDL-ESM4
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
# ...

# %% [markdown]
# ### _Copia de la descarga en caso de que se pierda_

# %% [raw]
# Starting download at :2025-03-19 13:37:13
#
# Downloading all south america
# Latitud boundaries : (-53.43306775676489, 13.592638486971083)
# Longitude boundaries : (-84.0833129206595, -34.73304413246237)
#
#
# Folder emppy , all good to proccede
# Current amount of files in folder 0
#
# Files are going into
#  D:\OneDrive\OneDrive - INTERCONEXION ELECTRICA S.A. E.S.P\01_CC_DOC\1_Raw_Data\4_Rain\02_NasaGPDX_SouthAmericaV3
#
# After 0-360 transformation (275.9166870793405, 325.2669558675376)
# Downloding files from GPDX Files.
#
# Modelo = GFDL-ESM4
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = MIROC6
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = MPI-ESM1-2-HR
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = MPI-ESM1-2-LR
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = MRI-ESM2-0
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = NorESM2-MM
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Modelo = EC-Earth3-Veg-LR
#
# 	Escenario = historical
#
# 		Chunk 1
# 			- Starts at 1985 - 1994
#
#
#
# 		Chunk 2
# 			- Starts at 1995 - 2004
#
#
#
# 		Chunk 3
# 			- Starts at 2005 - 2014
#
#
#
# 	Escenario = ssp245
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp370
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# 	Escenario = ssp585
#
# 		Chunk 1
# 			- Starts at 2015 - 2024
#
#
#
# 		Chunk 2
# 			- Starts at 2025 - 2034
#
#
#
# 		Chunk 3
# 			- Starts at 2035 - 2044
#
#
#
# 		Chunk 4
# 			- Starts at 2045 - 2054
#
#
#
# 		Chunk 5
# 			- Starts at 2055 - 2064
#
#
#
# 		Chunk 6
# 			- Starts at 2065 - 2074
#
#
#
# 		Chunk 7
# 			- Starts at 2075 - 2084
#
#
#
# 		Chunk 8
# 			- Starts at 2085 - 2094
#
#
#
# 		Chunk 9
# 			- Starts at 2095 - 2099
#
#
#
# Done !!!

# %% [markdown]
# ### 3. Valores faltantes

# %%
import os
import pandas as pd

from verify_download import verify_completness

url_output = r"D:\OneDrive\OneDrive - INTERCONEXION ELECTRICA S.A. E.S.P\01_CC_DOC\1_Raw_Data\4_Rain\02_NasaGPDX_SouthAmericaV3"
os.chdir(url_output)
gpdx_pr = [os.path.join( url_output,  var) for var in os.listdir(url_output) if '.txt' not in var]
all_models = pd.Series(gpdx_pr).str.extract(r"SAM_pr_(?P<Modelo>.+)_(?P<Escenario>historical|ssp\d{3})_(?P<fold>\d+).nc$")

# %%
all_models
# Out:
#                Modelo   Escenario fold
# 0    EC-Earth3-Veg-LR  historical    1
# 1    EC-Earth3-Veg-LR  historical    2
# 2    EC-Earth3-Veg-LR  historical    3
# 3    EC-Earth3-Veg-LR      ssp245    1
# 4    EC-Earth3-Veg-LR      ssp245    2
# ..                ...         ...  ...
# 205        NorESM2-MM      ssp585    5
# 206        NorESM2-MM      ssp585    6
# 207        NorESM2-MM      ssp585    7
# 208        NorESM2-MM      ssp585    8
# 209        NorESM2-MM      ssp585    9
#
# [210 rows x 3 columns]

# %%
gpdx_pr[:5]
# Out:
# ['SAM_pr_EC-Earth3-Veg-LR_historical_1.nc',
#  'SAM_pr_EC-Earth3-Veg-LR_historical_2.nc',
#  'SAM_pr_EC-Earth3-Veg-LR_historical_3.nc',
#  'SAM_pr_EC-Earth3-Veg-LR_ssp245_1.nc',
#  'SAM_pr_EC-Earth3-Veg-LR_ssp245_2.nc']

# %%
verify_completness(txt_names = gpdx_pr,var_name = 'pr',time_name = 'time')
# Out:
# SAM_pr_EC-Earth3-Veg-LR_historical_1.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_historical_2.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_historical_3.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_1.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_2.nc
# 	Complete
#
# Going good with 5
# SAM_pr_EC-Earth3-Veg-LR_ssp245_3.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_4.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_5.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_6.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_7.nc
# 	Complete
#
# Going good with 10
# SAM_pr_EC-Earth3-Veg-LR_ssp245_8.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp245_9.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp370_1.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp370_2.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp370_3.nc
# 	Complete
#
# Going good with 15
# SAM_pr_EC-Earth3-Veg-LR_ssp370_4.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp370_5.nc
# 	Complete
#
# SAM_pr_EC-Earth3-Veg-LR_ssp370_6.nc
# ...
